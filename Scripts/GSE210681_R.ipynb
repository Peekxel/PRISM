# %%
system('wget "https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE210681&format=file&file=GSE210681%5Faggregated%2E2kG%2Elibrary%2Emtx%2Egene%5Fx%5Fcell%2ERDS%2Egz" -O GSE210681_aggregated.2kG.library.mtx.gene_x_cell.RDS.gz ')

# %%
data <- readRDS("./GSE210681_aggregated.2kG.library.mtx.gene_x_cell.RDS")

# %%
data
# Out:
#                             ANKEF1:GAAGGGACATCATTCACGCCT:AAACCCAAGAAGTCAT-scRNAseq_2kG_11AMDox_1
# MIR1302-2HG:ENSG00000243485 0
# FAM138A:ENSG00000237613     0
# OR4F5:ENSG00000186092       0
# AL627309.1:ENSG00000238009  0
# AL627309.3:ENSG00000239945  0
# AL627309.2:ENSG00000239906  0
# AL627309.5:ENSG00000241860  0
# AL627309.4:ENSG00000241599  0
# AP006222.2:ENSG00000286448  0
# AL732372.1:ENSG00000236601  0
# OR4F29:ENSG00000284733      0
# AC114498.1:ENSG00000235146  0
# OR4F16:ENSG00000284662      0
# AL669831.2:ENSG00000229905  0
# LINC01409:ENSG00000237491   1
# FAM87B:ENSG00000177757      0
# LINC01128:ENSG00000228794   0
# LINC00115:ENSG00000225880   0
# FAM41C:ENSG00000230368      0
# AL645608.6:ENSG00000272438  0
# AL645608.2:ENSG00000230699  0
# AL645608.4:ENSG00000241180  0
# LINC02593:ENSG00000223764   0
# SAMD11:ENSG00000187634      0
# NOC2L:ENSG00000188976       0
# KLHL17:ENSG00000187961      0
# PLEKHN1:ENSG00000187583     0
# PERM1:ENSG00000187642       0
# ...

# %%
dim(data)
# Out:
# [1]  36601 214449

# %%
library(Matrix)
data <- as(data, "dgCMatrix")

# %%
gc()
# Out:
#        used      (Mb)   gc trigger  (Mb)     max used    (Mb)
# Ncells   1974853  105.5     2977781    159.1     2977781    159.1
# Vcells 980315998 7479.3 15076912530 115027.8 15704125448 119813.0

# %%
rownames(data)
# Out:
#     [1] "MIR1302-2HG:ENSG00000243485"       "FAM138A:ENSG00000237613"
#     [3] "OR4F5:ENSG00000186092"             "AL627309.1:ENSG00000238009"
#     [5] "AL627309.3:ENSG00000239945"        "AL627309.2:ENSG00000239906"
#     [7] "AL627309.5:ENSG00000241860"        "AL627309.4:ENSG00000241599"
#     [9] "AP006222.2:ENSG00000286448"        "AL732372.1:ENSG00000236601"
#    [11] "OR4F29:ENSG00000284733"            "AC114498.1:ENSG00000235146"
#    [13] "OR4F16:ENSG00000284662"            "AL669831.2:ENSG00000229905"
#    [15] "LINC01409:ENSG00000237491"         "FAM87B:ENSG00000177757"
#    [17] "LINC01128:ENSG00000228794"         "LINC00115:ENSG00000225880"
#    [19] "FAM41C:ENSG00000230368"            "AL645608.6:ENSG00000272438"
#    [21] "AL645608.2:ENSG00000230699"        "AL645608.4:ENSG00000241180"
#    [23] "LINC02593:ENSG00000223764"         "SAMD11:ENSG00000187634"
#    [25] "NOC2L:ENSG00000188976"             "KLHL17:ENSG00000187961"
# ...

# %%
writeMM(data, "./matrix.mtx")
# Out:
# NULL

# %%
write.table(rownames(data), 'features.tsv', sep='\t')
write.table(colnames(data), 'barcodes.tsv', sep='\t')
