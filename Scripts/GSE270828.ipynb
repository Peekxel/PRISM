# %%
# %cd /content/drive/MyDrive/GSE270828/
# Out:
# /content/drive/MyDrive/GSE270828

# %%
# !tar -zxvf GSE270828_h5ad.tar.gz
# Out:
# convert_to_h5ad.R
# GSE270828_Merged_CountMatrix.rds
# GSE270828_merged.h5ad
# GSE270828_feature_README.csv
# GSE270828_merged.h5ad
# convert_to_h5ad.R

# %%
# %pip install -q scanpy
import scanpy as sc
import pandas as pd
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.4 MB/s eta 0:00:00
# ...

# %%
adata = sc.read_h5ad("./GSE270828_merged.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 87896 × 19698
#     obs: 'nCount_RNA', 'nFeature_RNA', 'nCount_crispr', 'nFeature_crispr', 'lane', 'replicate', 'scDblFinder.sample', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'percent.mt', 'num_guide', 'guide', 'har', 'perturbation_name'

# %%
adata.obs['organism'] = "Humans (Homo sapiens)"
adata.obs['organ'] = "Brain (Cerebral Cortex)"
adata.obs['celltype'] = 'Neural Stem Cell (NSC)'
adata.write_h5ad("./GSE270828_merged.h5ad")

# %%
# !gzip -d GSE270828_h5ad.tar.gz && tar -rvf GSE270828_h5ad.tar GSE270828_merged.h5ad && gzip GSE270828_h5ad.tar
# Out:
# GSE270828_merged.h5ad
# tar: GSE270828_merged.h5ad: file changed as we read it
